# %%
import pandas as pd
import numpy as np
import datetime
import time

# %% [markdown]
# # COMBINING DAILY SOLAR DATA WITH CAPACITY INFO
# 1. Get solar capacity, S solar, E solar, W solar
# 2. Iterate through manipulated data and append to row
# 3. Every time you get to a new data id, get next row from metadata
# 4. Repeat

# %%
# import data
metadata = pd.read_csv('metadata.csv')
metadata.drop(index=metadata.index[0], axis=0, inplace=True)
keeper_columns = ['dataid', 'pv', 'pv_panel_direction', 'total_amount_of_pv', 'amount_of_south_facing_pv', 'amount_of_west_facing_pv',
                 'amount_of_east_facing_pv']
metadata = metadata[keeper_columns]
metadata[["dataid", "total_amount_of_pv"]] = metadata[["dataid", "total_amount_of_pv"]].apply(pd.to_numeric)

solardata = pd.read_csv('manipulated_15minute_data_austin.csv')
solardata[["dataid"]] = solardata[["dataid"]].apply(pd.to_numeric)

metadata
# Out:
#       dataid   pv pv_panel_direction  total_amount_of_pv  \
# 1       2836  NaN                NaN                 NaN
# 2       2743  NaN                NaN                 NaN
# 3       5323  NaN                NaN                 NaN
# 4       8560  NaN                NaN                 NaN
# 5       3313  NaN                NaN                 NaN
# ...      ...  ...                ...                 ...
# 1728   11360  yes               West                5.25
# 1729    5361  NaN                NaN                 NaN
# 1730    8217  NaN                NaN                 NaN
# 1731    8057  yes                NaN                 NaN
# 1732    7314  yes                NaN                 NaN
#
#      amount_of_south_facing_pv amount_of_west_facing_pv  \
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# ...                        ...                      ...
# 1728                       NaN                     5.25
# 1729                       NaN                      NaN
# 1730                       NaN                      NaN
# 1731                       NaN                      NaN
# 1732                       NaN                      NaN
#
#      amount_of_east_facing_pv
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 1728                      NaN
# 1729                      NaN
# 1730                      NaN
# 1731                      NaN
# 1732                      NaN
#
# [1732 rows x 7 columns]

# %%
# Combine info

merged = solardata.merge(metadata, on='dataid', how="inner")
merged.head()
# Out:
#    dataid       local_15min   grid  solar    leg1v    leg2v   pv  \
# 0     661  11/21/2018 15:15  0.124  0.276  123.915  124.277  yes
# 1     661  11/21/2018 15:30  0.251  0.167  123.959  124.293  yes
# 2     661  11/21/2018 15:45  0.419  0.179  123.886  124.240  yes
# 3     661  11/21/2018 16:00  0.833  0.076  123.880  124.175  yes
# 4     661  11/21/2018 16:15  1.105  0.064  123.633  124.226  yes
#
#   pv_panel_direction  total_amount_of_pv amount_of_south_facing_pv  \
# 0              South                 6.3                       6.3
# 1              South                 6.3                       6.3
# 2              South                 6.3                       6.3
# 3              South                 6.3                       6.3
# 4              South                 6.3                       6.3
#
#   amount_of_west_facing_pv amount_of_east_facing_pv
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN

# %%
# Create "Percent Output" column
# Unit Assumptions. Near certain these are right:
#      -"total amount of pv" unit is kW (looked at average PV installation sizes)
#      -"solar" and "grid" units are kW (looked at average home consumption)
# IMPROVEMENT AREA: Does not account for orientation of panels
merged["Percent Output"] = merged["solar"] / merged["total_amount_of_pv"]
merged.head()
# Out:
#    dataid       local_15min   grid  solar    leg1v    leg2v   pv  \
# 0     661  11/21/2018 15:15  0.124  0.276  123.915  124.277  yes
# 1     661  11/21/2018 15:30  0.251  0.167  123.959  124.293  yes
# 2     661  11/21/2018 15:45  0.419  0.179  123.886  124.240  yes
# 3     661  11/21/2018 16:00  0.833  0.076  123.880  124.175  yes
# 4     661  11/21/2018 16:15  1.105  0.064  123.633  124.226  yes
#
#   pv_panel_direction  total_amount_of_pv amount_of_south_facing_pv  \
# 0              South                 6.3                       6.3
# 1              South                 6.3                       6.3
# 2              South                 6.3                       6.3
# 3              South                 6.3                       6.3
# 4              South                 6.3                       6.3
#
#   amount_of_west_facing_pv amount_of_east_facing_pv  Percent Output
# 0                      NaN                      NaN        0.043810
# 1                      NaN                      NaN        0.026508
# 2                      NaN                      NaN        0.028413
# 3                      NaN                      NaN        0.012063
# 4                      NaN                      NaN        0.010159

# %%
# merge weather and solar data
# IMPROVEMENT AREA: drops all solar info except 'percent output'
merged = merged[['dataid','local_15min','Percent Output']]
weatherdata = pd.read_csv('Compiled Weather Data.csv')

# Converting join columns to matching datetime data types
merged['local_15min'] = pd.to_datetime(merged['local_15min'])
weatherdata['datetime'] = pd.to_datetime(weatherdata['datetime'])

# %%
trainingdata = merged.merge(weatherdata, left_on='local_15min', right_on='datetime', how="inner")
trainingdata.head()
# Out:
#    dataid local_15min  Percent Output        name   datetime  temp  feelslike  \
# 0     661  2018-01-01             NaN  Austin, TX 2018-01-01  26.9       17.2
# 1    1642  2018-01-01       -0.000785  Austin, TX 2018-01-01  26.9       17.2
# 2    2335  2018-01-01       -0.001014  Austin, TX 2018-01-01  26.9       17.2
# 3    2361  2018-01-01             NaN  Austin, TX 2018-01-01  26.9       17.2
# 4    2818  2018-01-01       -0.000928  Austin, TX 2018-01-01  26.9       17.2
#
#     dew  humidity  precip  ...  sealevelpressure  cloudcover  visibility  \
# 0  21.1     78.65     0.0  ...            1038.3       100.0         9.9
# 1  21.1     78.65     0.0  ...            1038.3       100.0         9.9
# 2  21.1     78.65     0.0  ...            1038.3       100.0         9.9
# 3  21.1     78.65     0.0  ...            1038.3       100.0         9.9
# 4  21.1     78.65     0.0  ...            1038.3       100.0         9.9
#
#    solarradiation  solarenergy  uvindex  severerisk  conditions    icon  \
# 0             NaN          NaN      NaN         NaN    Overcast  cloudy
# 1             NaN          NaN      NaN         NaN    Overcast  cloudy
# 2             NaN          NaN      NaN         NaN    Overcast  cloudy
# 3             NaN          NaN      NaN         NaN    Overcast  cloudy
# 4             NaN          NaN      NaN         NaN    Overcast  cloudy
#
#                                         stations
# 0  KATT,KAUS,72064800230,72254013904,72254413958
# 1  KATT,KAUS,72064800230,72254013904,72254413958
# 2  KATT,KAUS,72064800230,72254013904,72254413958
# 3  KATT,KAUS,72064800230,72254013904,72254413958
# 4  KATT,KAUS,72064800230,72254013904,72254413958
#
# [5 rows x 27 columns]

# %%
## IMPROVEMENT OPPORTUNITY: 'conditions' categorical variable is not used
trainingdata.drop(['name', 'datetime', 'dataid', 'stations', 'icon', 'conditions'], axis=1, inplace=True) 
list(trainingdata.columns.values)
# Out:
# ['local_15min',
#  'Percent Output',
#  'temp',
#  'feelslike',
#  'dew',
#  'humidity',
#  'precip',
#  'precipprob',
#  'preciptype',
#  'snow',
#  'snowdepth',
#  'windgust',
#  'windspeed',
#  'winddir',
#  'sealevelpressure',
#  'cloudcover',
#  'visibility',
#  'solarradiation',
#  'solarenergy',
#  'uvindex',
#  'severerisk']

# %%
trainingdata.dtypes
# Out:
# local_15min         datetime64[ns]
# Percent Output             float64
# temp                       float64
# feelslike                  float64
# dew                        float64
# humidity                   float64
# precip                     float64
# precipprob                 float64
# preciptype                 float64
# snow                         int64
# snowdepth                    int64
# windgust                   float64
# windspeed                  float64
# winddir                    float64
# sealevelpressure           float64
# cloudcover                 float64
# visibility                 float64
# solarradiation             float64
# solarenergy                float64
# uvindex                    float64
# severerisk                 float64
# dtype: object

# %%
# turn datetime into unix timestamp
trainingdata['local_15min'] = trainingdata['local_15min'].map(lambda x: time.mktime(x.timetuple()))

# %%
# turn datetime into 4 new columns: year, month, day, time
trainingdata['year'] = trainingdata['local_15min'].dt.year
trainingdata['month'] = trainingdata['local_15min'].dt.month
trainingdata['day'] = trainingdata['local_15min'].dt.day
trainingdata['time'] = trainingdata['local_15min'].dt.hour + trainingdata['local_15min'].dt.minute / 60

# %%
# reorder so the predicted feature is at the end
column_to_reorder = trainingdata.pop('Percent Output')
trainingdata.insert(len(trainingdata. columns), 'Percent Output', column_to_reorder)

trainingdata.dtypes
# Out:
# local_15min         datetime64[ns]
# temp                       float64
# feelslike                  float64
# dew                        float64
# humidity                   float64
# precip                     float64
# precipprob                 float64
# preciptype                 float64
# snow                         int64
# snowdepth                    int64
# windgust                   float64
# windspeed                  float64
# winddir                    float64
# sealevelpressure           float64
# cloudcover                 float64
# visibility                 float64
# solarradiation             float64
# solarenergy                float64
# uvindex                    float64
# severerisk                 float64
# year                         int64
# month                        int64
# day                          int64
# time                       float64
# Percent Output             float64
# dtype: object

# %%
trainingdata.tail()
# Out:
#               local_15min  temp  feelslike   dew  humidity  precip  \
# 73787 2018-08-31 23:00:00  83.8       88.1  69.9     63.08     0.0
# 73788 2018-08-31 23:00:00  83.8       88.1  69.9     63.08     0.0
# 73789 2018-08-31 23:00:00  83.8       88.1  69.9     63.08     0.0
# 73790 2018-08-31 23:00:00  83.8       88.1  69.9     63.08     0.0
# 73791 2018-08-31 23:00:00  83.8       88.1  69.9     63.08     0.0
#
#        precipprob  preciptype  snow  snowdepth  ...  visibility  \
# 73787         NaN         NaN     0          0  ...         9.9
# 73788         NaN         NaN     0          0  ...         9.9
# 73789         NaN         NaN     0          0  ...         9.9
# 73790         NaN         NaN     0          0  ...         9.9
# 73791         NaN         NaN     0          0  ...         9.9
#
#        solarradiation  solarenergy  uvindex  severerisk  year  month  day  \
# 73787             NaN          NaN      NaN         NaN  2018      8   31
# 73788             NaN          NaN      NaN         NaN  2018      8   31
# 73789             NaN          NaN      NaN         NaN  2018      8   31
# 73790             NaN          NaN      NaN         NaN  2018      8   31
# 73791             NaN          NaN      NaN         NaN  2018      8   31
#
#        time  Percent Output
# 73787  23.0             NaN
# 73788  23.0       -0.001042
# 73789  23.0       -0.000222
# 73790  23.0             NaN
# 73791  23.0       -0.001304
#
# [5 rows x 25 columns]

# %%
trainingdata.drop(['local_15min'], axis=1, inplace=True)

# %%
trainingdata.describe()
# Out:
#               temp    feelslike          dew     humidity       precip  \
# count  9231.000000  9231.000000  9231.000000  9231.000000  9231.000000
# mean     79.676785    80.713541    54.160925    44.645994     0.003705
# std      17.517095    20.088386    17.012247    17.153555     0.053846
# min      25.000000    13.700000     5.500000     9.380000     0.000000
# 25%      68.100000    68.100000    47.100000    31.640000     0.000000
# 50%      81.100000    82.300000    61.100000    41.880000     0.000000
# 75%      94.600000    97.500000    65.900000    54.500000     0.000000
# max     104.600000   105.300000    75.800000    97.070000     1.100000
#
#          snow  snowdepth     windgust    windspeed      winddir  ...  \
# count  9231.0     9231.0  9231.000000  9231.000000  9231.000000  ...
# mean      0.0        0.0    20.669527     9.639248   173.017983  ...
# std       0.0        0.0     3.832644     2.811253    88.716513  ...
# min       0.0        0.0    16.100000     1.800000     1.000000  ...
# 25%       0.0        0.0    18.100000     7.800000   147.500000  ...
# 50%       0.0        0.0    19.700000     9.300000   176.000000  ...
# 75%       0.0        0.0    22.700000    11.400000   200.000000  ...
# max       0.0        0.0    37.500000    19.500000   360.000000  ...
#
#         cloudcover   visibility  solarradiation  solarenergy      uvindex  \
# count  9231.000000  9231.000000     9231.000000  9231.000000  9231.000000
# mean     40.603586     9.735337      387.443506     1.393078     3.840646
# std      36.135209     0.743708      263.732556     0.949083     2.683334
# min       0.000000     1.600000        4.000000     0.000000     0.000000
# 25%       9.100000     9.900000      148.000000     0.500000     1.000000
# 50%      23.000000     9.900000      372.000000     1.300000     4.000000
# 75%      80.900000     9.900000      621.000000     2.200000     6.000000
# max     100.000000     9.900000      902.000000     3.200000     9.000000
#
#          year        month          day         time  Percent Output
# count  9231.0  9231.000000  9231.000000  9231.000000     9231.000000
# mean   2018.0     4.846929    16.221211    14.345033        0.357038
# std       0.0     2.772890     8.719142     2.901415        0.231429
# min    2018.0     1.000000     1.000000     8.000000       -0.010518
# 25%    2018.0     3.000000     9.000000    12.000000        0.144495
# 50%    2018.0     3.000000    16.000000    14.000000        0.378507
# 75%    2018.0     8.000000    23.000000    17.000000        0.567619
# max    2018.0     8.000000    31.000000    21.000000        0.829048
#
# [8 rows x 21 columns]

# %%
trainingdata.drop(['precipprob','preciptype','severerisak'], axis=1, inplace=True)

# %%
trainingdata.dropna(inplace=True)

# %%
trainingdata.to_csv("SolarTrainingData.csv")
