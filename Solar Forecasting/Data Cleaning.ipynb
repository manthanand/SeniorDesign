# %%
import pandas as pd
import numpy as np
import datetime
import time

# %% [markdown]
# # COMBINING DAILY SOLAR DATA WITH CAPACITY INFO
# 1. Get solar capacity, S solar, E solar, W solar
# 2. Iterate through manipulated data and append to row
# 3. Every time you get to a new data id, get next row from metadata
# 4. Repeat

# %%
# import data
metadata = pd.read_csv('metadata.csv')
metadata.drop(index=metadata.index[0], axis=0, inplace=True)
keeper_columns = ['dataid', 'pv', 'pv_panel_direction', 'total_amount_of_pv', 'amount_of_south_facing_pv', 'amount_of_west_facing_pv',
                 'amount_of_east_facing_pv']
metadata = metadata[keeper_columns]
metadata[["dataid", "total_amount_of_pv"]] = metadata[["dataid", "total_amount_of_pv"]].apply(pd.to_numeric)

solardata = pd.read_csv('manipulated_15minute_data_austin.csv')
solardata[["dataid"]] = solardata[["dataid"]].apply(pd.to_numeric)
solardata.dropna(inplace=True)

metadata
# Out:
#       dataid   pv pv_panel_direction  total_amount_of_pv  \
# 1       2836  NaN                NaN                 NaN
# 2       2743  NaN                NaN                 NaN
# 3       5323  NaN                NaN                 NaN
# 4       8560  NaN                NaN                 NaN
# 5       3313  NaN                NaN                 NaN
# ...      ...  ...                ...                 ...
# 1728   11360  yes               West                5.25
# 1729    5361  NaN                NaN                 NaN
# 1730    8217  NaN                NaN                 NaN
# 1731    8057  yes                NaN                 NaN
# 1732    7314  yes                NaN                 NaN
#
#      amount_of_south_facing_pv amount_of_west_facing_pv  \
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# ...                        ...                      ...
# 1728                       NaN                     5.25
# 1729                       NaN                      NaN
# 1730                       NaN                      NaN
# 1731                       NaN                      NaN
# 1732                       NaN                      NaN
#
#      amount_of_east_facing_pv
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# ...                       ...
# 1728                      NaN
# 1729                      NaN
# 1730                      NaN
# 1731                      NaN
# 1732                      NaN
#
# [1732 rows x 7 columns]

# %%
# Combine info

merged = solardata.merge(metadata, on='dataid', how="inner")
merged.dropna(inplace=True)
merged.head()
# Out:
#         dataid      local_15min   grid  solar    leg1v    leg2v   pv  \
# 173447    3039  5/15/2018 10:15  0.427  1.298  123.580  123.757  yes
# 173448    3039  5/15/2018 10:30  0.775  0.942  123.441  123.528  yes
# 173449    3039  5/15/2018 10:45 -0.065  1.817  123.614  123.792  yes
# 173450    3039  5/15/2018 11:00 -0.474  2.197  123.648  123.800  yes
# 173451    3039  5/15/2018 11:15 -0.589  2.317  123.797  123.999  yes
#
#        pv_panel_direction  total_amount_of_pv amount_of_south_facing_pv  \
# 173447               West                6.25                       0.0
# 173448               West                6.25                       0.0
# 173449               West                6.25                       0.0
# 173450               West                6.25                       0.0
# 173451               West                6.25                       0.0
#
#        amount_of_west_facing_pv amount_of_east_facing_pv
# 173447                     6.25                      0.0
# 173448                     6.25                      0.0
# 173449                     6.25                      0.0
# 173450                     6.25                      0.0
# 173451                     6.25                      0.0

# %%
# Create "Percent Output" column
# Unit Assumptions. Near certain these are right:
#      -"total amount of pv" unit is kW (looked at average PV installation sizes)
#      -"solar" and "grid" units are kW (looked at average home consumption)
# IMPROVEMENT AREA: Does not account for orientation of panels
merged["Percent Output"] = merged["solar"] / merged["total_amount_of_pv"]
merged.head()
# Out:
#         dataid      local_15min   grid  solar    leg1v    leg2v   pv  \
# 173447    3039  5/15/2018 10:15  0.427  1.298  123.580  123.757  yes
# 173448    3039  5/15/2018 10:30  0.775  0.942  123.441  123.528  yes
# 173449    3039  5/15/2018 10:45 -0.065  1.817  123.614  123.792  yes
# 173450    3039  5/15/2018 11:00 -0.474  2.197  123.648  123.800  yes
# 173451    3039  5/15/2018 11:15 -0.589  2.317  123.797  123.999  yes
#
#        pv_panel_direction  total_amount_of_pv amount_of_south_facing_pv  \
# 173447               West                6.25                       0.0
# 173448               West                6.25                       0.0
# 173449               West                6.25                       0.0
# 173450               West                6.25                       0.0
# 173451               West                6.25                       0.0
#
#        amount_of_west_facing_pv amount_of_east_facing_pv  Percent Output
# 173447                     6.25                      0.0         0.20768
# 173448                     6.25                      0.0         0.15072
# 173449                     6.25                      0.0         0.29072
# 173450                     6.25                      0.0         0.35152
# 173451                     6.25                      0.0         0.37072

# %%
# Transforming output data to include time-series information
# IMPROVEMENT AREA: Fiddle with how far back you want the data to go to inform future predictions

current_house, onefourtyfive_ago, onethirty_ago, onefifteen_ago, one_ago, fourtyfive_ago, thirty_ago, fifteen_ago = None, None, None, None, None, None, None, None
merged['onefourtyfive_ago'] = None
merged['onethirty_ago'] = None
merged['onefifteen_ago'] = None
merged['one_ago'] = None
merged['fourtyfive_ago'] = None
merged['thirty_ago'] = None
merged['fifteen_ago'] = None

merged.head()

for i, row in merged.iterrows():
    
    if (current_house == row["dataid"]):              # if you are continuing with the same house
        merged.at[i,'onefourtyfive_ago'] = onefourtyfive_ago
        merged.at[i,'onethirty_ago'] = onethirty_ago
        merged.at[i,'onefifteen_ago'] = onefifteen_ago
        merged.at[i,'one_ago'] = one_ago
        merged.at[i,'fourtyfive_ago'] = fourtyfive_ago
        merged.at[i,'thirty_ago'] = thirty_ago
        merged.at[i,'fifteen_ago'] = fifteen_ago
        
        onefourtyfive_ago = onethirty_ago
        onethirty_ago = onefifteen_ago
        onefifteen_ago = one_ago
        one_ago = fourtyfive_ago
        fourtyfive_ago = thirty_ago                       # refresh previous data variables
        thirty_ago = fifteen_ago
        fifteen_ago = row["Percent Output"]
        
    else:                                             # if a row encounters a new house
        current_house = row["dataid"]                     # refresh previous data variables
        onefourtyfive_ago, onethirty_ago, onefiteen_ago, one_ago, fourtyfive_ago, thirty_ago = None, None, None, None, None, None        
        fifteen_ago = row["Percent Output"]

# %%
merged.head(20)
# Out:
#         dataid      local_15min   grid  solar    leg1v    leg2v   pv  \
# 173447    3039  5/15/2018 10:15  0.427  1.298  123.580  123.757  yes
# 173448    3039  5/15/2018 10:30  0.775  0.942  123.441  123.528  yes
# 173449    3039  5/15/2018 10:45 -0.065  1.817  123.614  123.792  yes
# 173450    3039  5/15/2018 11:00 -0.474  2.197  123.648  123.800  yes
# 173451    3039  5/15/2018 11:15 -0.589  2.317  123.797  123.999  yes
# 173452    3039  5/15/2018 11:30 -0.826  2.584  123.703  124.031  yes
# 173453    3039  5/15/2018 11:45 -0.986  2.731  123.596  123.726  yes
# 173454    3039   5/16/2018 7:15  1.400  0.098  122.649  122.805  yes
# 173455    3039   5/16/2018 7:30  1.422  0.131  122.503  122.702  yes
# 173456    3039   5/16/2018 7:45  1.347  0.164  122.501  122.670  yes
# 173457    3039   5/16/2018 8:00  1.260  0.203  122.439  122.581  yes
# 173458    3039   5/16/2018 8:15  1.267  0.206  122.319  122.521  yes
# 173459    3039   5/16/2018 8:30  1.320  0.208  122.176  122.261  yes
# 173460    3039   5/16/2018 8:45  1.286  0.225  122.181  122.318  yes
# 173461    3039   5/16/2018 9:00  1.194  0.292  122.538  122.721  yes
# 173462    3039   5/16/2018 9:15  1.026  0.462  122.680  122.789  yes
# 173463    3039   5/16/2018 9:30  0.934  0.627  122.629  122.915  yes
# 173464    3039   5/16/2018 9:45  0.497  0.992  122.768  122.993  yes
# 173465    3039  5/16/2018 10:00  0.630  0.915  122.967  123.114  yes
# 173466    3039    1/1/2018 1:00  1.463 -0.004   87.980   88.151  yes
#
#        pv_panel_direction  total_amount_of_pv amount_of_south_facing_pv  \
# 173447               West                6.25                       0.0
# 173448               West                6.25                       0.0
# 173449               West                6.25                       0.0
# 173450               West                6.25                       0.0
# 173451               West                6.25                       0.0
# 173452               West                6.25                       0.0
# 173453               West                6.25                       0.0
# 173454               West                6.25                       0.0
# 173455               West                6.25                       0.0
# 173456               West                6.25                       0.0
# 173457               West                6.25                       0.0
# 173458               West                6.25                       0.0
# 173459               West                6.25                       0.0
# 173460               West                6.25                       0.0
# 173461               West                6.25                       0.0
# 173462               West                6.25                       0.0
# 173463               West                6.25                       0.0
# 173464               West                6.25                       0.0
# 173465               West                6.25                       0.0
# 173466               West                6.25                       0.0
#
#        amount_of_west_facing_pv amount_of_east_facing_pv  Percent Output  \
# 173447                     6.25                      0.0         0.20768
# 173448                     6.25                      0.0         0.15072
# 173449                     6.25                      0.0         0.29072
# 173450                     6.25                      0.0         0.35152
# 173451                     6.25                      0.0         0.37072
# 173452                     6.25                      0.0         0.41344
# 173453                     6.25                      0.0         0.43696
# 173454                     6.25                      0.0         0.01568
# 173455                     6.25                      0.0         0.02096
# 173456                     6.25                      0.0         0.02624
# 173457                     6.25                      0.0         0.03248
# 173458                     6.25                      0.0         0.03296
# 173459                     6.25                      0.0         0.03328
# 173460                     6.25                      0.0         0.03600
# 173461                     6.25                      0.0         0.04672
# 173462                     6.25                      0.0         0.07392
# 173463                     6.25                      0.0         0.10032
# 173464                     6.25                      0.0         0.15872
# 173465                     6.25                      0.0         0.14640
# 173466                     6.25                      0.0        -0.00064
#
#        onefourtyfive_ago onethirty_ago onefifteen_ago  one_ago fourtyfive_ago  \
# 173447              None          None           None     None           None
# 173448              None          None           None     None           None
# 173449              None          None           None     None           None
# 173450              None          None           None     None        0.20768
# 173451              None          None           None  0.20768        0.15072
# 173452              None          None        0.20768  0.15072        0.29072
# 173453              None       0.20768        0.15072  0.29072        0.35152
# 173454           0.20768       0.15072        0.29072  0.35152        0.37072
# 173455           0.15072       0.29072        0.35152  0.37072        0.41344
# 173456           0.29072       0.35152        0.37072  0.41344        0.43696
# 173457           0.35152       0.37072        0.41344  0.43696        0.01568
# 173458           0.37072       0.41344        0.43696  0.01568        0.02096
# 173459           0.41344       0.43696        0.01568  0.02096        0.02624
# 173460           0.43696       0.01568        0.02096  0.02624        0.03248
# 173461           0.01568       0.02096        0.02624  0.03248        0.03296
# 173462           0.02096       0.02624        0.03248  0.03296        0.03328
# 173463           0.02624       0.03248        0.03296  0.03328          0.036
# 173464           0.03248       0.03296        0.03328    0.036        0.04672
# 173465           0.03296       0.03328          0.036  0.04672        0.07392
# 173466           0.03328         0.036        0.04672  0.07392        0.10032
#
#        thirty_ago fifteen_ago
# 173447       None        None
# 173448       None     0.20768
# 173449    0.20768     0.15072
# 173450    0.15072     0.29072
# 173451    0.29072     0.35152
# 173452    0.35152     0.37072
# 173453    0.37072     0.41344
# 173454    0.41344     0.43696
# 173455    0.43696     0.01568
# 173456    0.01568     0.02096
# 173457    0.02096     0.02624
# 173458    0.02624     0.03248
# 173459    0.03248     0.03296
# 173460    0.03296     0.03328
# 173461    0.03328       0.036
# 173462      0.036     0.04672
# 173463    0.04672     0.07392
# 173464    0.07392     0.10032
# 173465    0.10032     0.15872
# 173466    0.15872      0.1464

# %%
# merge weather and solar data
# IMPROVEMENT AREA: drops all solar info except 'percent output'
merged = merged[['dataid','local_15min','Percent Output', 'onefourtyfive_ago', 'onethirty_ago', 'onefifteen_ago', 'one_ago', 'fourtyfive_ago', 'thirty_ago', 'fifteen_ago']]
weatherdata = pd.read_csv('Compiled Weather Data.csv')

# Converting join columns to matching datetime data types
merged['local_15min'] = pd.to_datetime(merged['local_15min'])
weatherdata['datetime'] = pd.to_datetime(weatherdata['datetime'])

# %%
trainingdata = merged.merge(weatherdata, left_on='local_15min', right_on='datetime', how="inner")
trainingdata.head()
# Out:
#    dataid         local_15min  Percent Output onefourtyfive_ago onethirty_ago  \
# 0    3039 2018-01-01 01:00:00        -0.00064           0.03328         0.036
# 1    3039 2018-01-01 02:00:00        -0.00080           0.10032       0.15872
# 2    3039 2018-01-01 05:00:00        -0.00080           -0.0008       -0.0008
# 3    3039 2018-01-01 06:00:00        -0.00080           -0.0008       -0.0008
# 4    3039 2018-01-01 08:00:00         0.01696           -0.0008       -0.0008
#
#   onefifteen_ago  one_ago fourtyfive_ago thirty_ago fifteen_ago  ...  \
# 0        0.04672  0.07392        0.10032    0.15872      0.1464  ...
# 1         0.1464 -0.00064        -0.0008    -0.0008     -0.0008  ...
# 2        -0.0008  -0.0008        -0.0008    -0.0008     -0.0008  ...
# 3        -0.0008  -0.0008        -0.0008    -0.0008     -0.0008  ...
# 4        -0.0008  -0.0008        -0.0008    -0.0008     -0.0008  ...
#
#   sealevelpressure cloudcover  visibility  solarradiation  solarenergy  \
# 0           1038.1      100.0         9.9             NaN          NaN
# 1           1038.6      100.0         9.9             NaN          NaN
# 2           1039.7      100.0         9.9             NaN          NaN
# 3           1040.1      100.0         9.9             NaN          NaN
# 4           1041.6       97.5         9.9            18.0          0.1
#
#    uvindex  severerisk  conditions    icon  \
# 0      NaN         NaN    Overcast  cloudy
# 1      NaN         NaN    Overcast  cloudy
# 2      NaN         NaN    Overcast  cloudy
# 3      NaN         NaN    Overcast  cloudy
# 4      0.0         NaN    Overcast  cloudy
#
#                                             stations
# 0  KATT,KAUS,72064800230,KEDC,72254013904,7225441...
# 1  KATT,KAUS,72064800230,KEDC,72254013904,7225441...
# 2  KATT,KAUS,72064800230,KEDC,72254013904,7225441...
# 3  KATT,KAUS,72064800230,KEDC,72254013904,7225441...
# 4  KATT,KAUS,72064800230,E4737,KEDC,72254013904,7...
#
# [5 rows x 34 columns]

# %%
merged.head()
# Out:
#         dataid         local_15min  Percent Output onefourtyfive_ago  \
# 173447    3039 2018-05-15 10:15:00         0.20768              None
# 173448    3039 2018-05-15 10:30:00         0.15072              None
# 173449    3039 2018-05-15 10:45:00         0.29072              None
# 173450    3039 2018-05-15 11:00:00         0.35152              None
# 173451    3039 2018-05-15 11:15:00         0.37072              None
#
#        onethirty_ago onefifteen_ago  one_ago fourtyfive_ago thirty_ago  \
# 173447          None           None     None           None       None
# 173448          None           None     None           None       None
# 173449          None           None     None           None    0.20768
# 173450          None           None     None        0.20768    0.15072
# 173451          None           None  0.20768        0.15072    0.29072
#
#        fifteen_ago
# 173447        None
# 173448     0.20768
# 173449     0.15072
# 173450     0.29072
# 173451     0.35152

# %%
## IMPROVEMENT OPPORTUNITY: 'conditions' categorical variable is not used
trainingdata.drop(['name', 'datetime', 'dataid', 'stations', 'icon', 'conditions'], axis=1, inplace=True) 
list(trainingdata.columns.values)
# Out:
# ['local_15min',
#  'Percent Output',
#  'onefourtyfive_ago',
#  'onethirty_ago',
#  'onefifteen_ago',
#  'one_ago',
#  'fourtyfive_ago',
#  'thirty_ago',
#  'fifteen_ago',
#  'temp',
#  'feelslike',
#  'dew',
#  'humidity',
#  'precip',
#  'precipprob',
#  'preciptype',
#  'snow',
#  'snowdepth',
#  'windgust',
#  'windspeed',
#  'winddir',
#  'sealevelpressure',
#  'cloudcover',
#  'visibility',
#  'solarradiation',
#  'solarenergy',
#  'uvindex',
#  'severerisk']

# %%
trainingdata.dtypes
# Out:
# local_15min          datetime64[ns]
# Percent Output              float64
# onefourtyfive_ago            object
# onethirty_ago                object
# onefifteen_ago               object
# one_ago                      object
# fourtyfive_ago               object
# thirty_ago                   object
# fifteen_ago                  object
# temp                        float64
# feelslike                   float64
# dew                         float64
# humidity                    float64
# precip                      float64
# precipprob                  float64
# preciptype                  float64
# snow                          int64
# snowdepth                     int64
# windgust                    float64
# windspeed                   float64
# winddir                     float64
# sealevelpressure            float64
# cloudcover                  float64
# visibility                  float64
# solarradiation              float64
# solarenergy                 float64
# uvindex                     float64
# severerisk                  float64
# dtype: object

# %%
# turn datetime into 4 new columns: year, month, day, time
trainingdata['year'] = trainingdata['local_15min'].dt.year
trainingdata['month'] = trainingdata['local_15min'].dt.month
trainingdata['day'] = trainingdata['local_15min'].dt.day
trainingdata['time'] = trainingdata['local_15min'].dt.hour + trainingdata['local_15min'].dt.minute / 60

# %%
# reorder so the predicted feature is at the end
column_to_reorder = trainingdata.pop('Percent Output')
trainingdata.insert(len(trainingdata. columns), 'Percent Output', column_to_reorder)

trainingdata.dtypes
# Out:
# local_15min          datetime64[ns]
# onefourtyfive_ago            object
# onethirty_ago                object
# onefifteen_ago               object
# one_ago                      object
# fourtyfive_ago               object
# thirty_ago                   object
# fifteen_ago                  object
# temp                        float64
# feelslike                   float64
# dew                         float64
# humidity                    float64
# precip                      float64
# precipprob                  float64
# preciptype                  float64
# snow                          int64
# snowdepth                     int64
# windgust                    float64
# windspeed                   float64
# winddir                     float64
# sealevelpressure            float64
# cloudcover                  float64
# visibility                  float64
# solarradiation              float64
# solarenergy                 float64
# uvindex                     float64
# severerisk                  float64
# year                          int64
# month                         int64
# day                           int64
# time                        float64
# Percent Output              float64
# dtype: object

# %%
trainingdata.tail()
# Out:
#              local_15min  temp  feelslike   dew  humidity  precip  precipprob  \
# 2872 2018-08-31 19:00:00  95.2       96.5  62.7     34.32     0.0         NaN
# 2873 2018-08-31 20:00:00  92.8       94.2  63.3     37.72     0.0         NaN
# 2874 2018-08-31 21:00:00  90.5       92.4  64.7     42.72     0.0         NaN
# 2875 2018-08-31 22:00:00  87.0       91.7  69.7     56.62     0.0         NaN
# 2876 2018-08-31 23:00:00  83.8       88.1  69.9     63.08     0.0         NaN
#
#       preciptype  snow  snowdepth  ...  visibility  solarradiation  \
# 2872         NaN     0          0  ...         9.9            89.0
# 2873         NaN     0          0  ...         9.9            14.0
# 2874         NaN     0          0  ...         9.9             NaN
# 2875         NaN     0          0  ...         9.9             NaN
# 2876         NaN     0          0  ...         9.9             NaN
#
#       solarenergy  uvindex  severerisk  year  month  day  time  Percent Output
# 2872          0.3      1.0         NaN  2018      8   31  19.0         0.21984
# 2873          0.1      0.0         NaN  2018      8   31  20.0        -0.00448
# 2874          NaN      NaN         NaN  2018      8   31  21.0        -0.00064
# 2875          NaN      NaN         NaN  2018      8   31  22.0        -0.00064
# 2876          NaN      NaN         NaN  2018      8   31  23.0        -0.00064
#
# [5 rows x 25 columns]

# %%
trainingdata.drop(['local_15min'], axis=1, inplace=True)

# %%
trainingdata.describe()
# Out:
#              temp   feelslike         dew    humidity      precip   snow  \
# count  504.000000  504.000000  504.000000  504.000000  504.000000  504.0
# mean    80.566071   81.720635   54.686310   44.245893    0.003770    0.0
# std     17.233098   19.705182   16.837449   17.230788    0.054365    0.0
# min     25.000000   13.700000    5.500000    9.380000    0.000000    0.0
# 25%     69.075000   69.075000   48.175000   31.325000    0.000000    0.0
# 50%     84.050000   86.050000   61.500000   41.685000    0.000000    0.0
# 75%     95.100000   97.825000   66.125000   54.010000    0.000000    0.0
# max    104.600000  105.300000   75.800000   97.070000    1.100000    0.0
#
#        snowdepth    windgust   windspeed     winddir  ...  cloudcover  \
# count      504.0  504.000000  504.000000  504.000000  ...  504.000000
# mean         0.0   20.681349    9.589881  170.744048  ...   39.777579
# std          0.0    3.860815    2.827702   87.112961  ...   35.542186
# min          0.0   16.100000    1.800000    1.000000  ...    0.000000
# 25%          0.0   18.100000    7.600000  146.000000  ...    9.500000
# 50%          0.0   19.700000    9.250000  174.500000  ...   22.800000
# 75%          0.0   22.550000   11.300000  198.000000  ...   75.100000
# max          0.0   37.500000   19.500000  360.000000  ...  100.000000
#
#        visibility  solarradiation  solarenergy     uvindex    year  \
# count  504.000000      504.000000   504.000000  504.000000   504.0
# mean     9.731151      393.680556     1.415278    3.902778  2018.0
# std      0.752598      265.282480     0.954588    2.701239     0.0
# min      1.600000        4.000000     0.000000    0.000000  2018.0
# 25%      9.900000      153.750000     0.600000    2.000000  2018.0
# 50%      9.900000      384.000000     1.400000    4.000000  2018.0
# 75%      9.900000      624.000000     2.200000    6.000000  2018.0
# max      9.900000      902.000000     3.200000    9.000000  2018.0
#
#             month         day        time  Percent Output
# count  504.000000  504.000000  504.000000      504.000000
# mean     4.988095   16.545635   14.382937        0.353057
# std      2.756496    8.711290    2.889308        0.214073
# min      1.000000    1.000000    8.000000       -0.004640
# 25%      3.000000   10.000000   12.000000        0.153080
# 50%      7.000000   16.000000   14.000000        0.411840
# 75%      8.000000   24.000000   17.000000        0.552760
# max      8.000000   31.000000   21.000000        0.683040
#
# [8 rows x 21 columns]

# %%
trainingdata.drop(['precipprob','preciptype','severerisk'], axis=1, inplace=True)

# %%
#IMPROVEMENT AREA: a lot of data is dropped here. This might be something from adding the new columns
trainingdata.dropna(inplace=True)

# %%
trainingdata.head()
# Out:
#     onefourtyfive_ago onethirty_ago onefifteen_ago  one_ago fourtyfive_ago  \
# 4             -0.0008       -0.0008        -0.0008  -0.0008        -0.0008
# 5             -0.0008       -0.0008        -0.0008  0.01696        0.02544
# 45             0.5184         0.524         0.5272    0.524        0.52176
# 130           0.01216       0.02208        0.03056  0.04384        0.10528
# 131           0.10528       0.08992         0.1624   0.1536        0.12272
#
#     thirty_ago fifteen_ago  temp  feelslike   dew  ...  cloudcover  \
# 4      -0.0008     -0.0008  25.0       14.1  11.4  ...        97.5
# 5      0.05808     0.08224  26.5       15.9  11.7  ...        94.3
# 45     0.51216    -0.00064  54.9       54.9  20.9  ...         6.2
# 130    0.08992      0.1624  58.1       58.1  53.9  ...        43.3
# 131    0.10432     0.12912  61.8       61.8  54.7  ...       100.0
#
#      visibility  solarradiation  solarenergy  uvindex  year  month  day  time  \
# 4           9.9            18.0          0.1      0.0  2018      1    1   8.0
# 5           9.9           266.0          1.0      3.0  2018      1    1  11.0
# 45          9.9           489.0          1.8      5.0  2018      1    3  15.0
# 130         9.9           175.0          0.6      2.0  2018      1    7  10.0
# 131         9.9           194.0          0.7      2.0  2018      1    7  11.0
#
#      Percent Output
# 4           0.01696
# 5           0.25280
# 45          0.50416
# 130         0.15360
# 131         0.14800
#
# [5 rows x 28 columns]

# %%
trainingdata.to_csv("Memory_SolarTrainingData.csv")
